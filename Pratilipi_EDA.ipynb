# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
user_interaction = pd.read_csv('/content/drive/MyDrive/user_interaction_pratilipi.csv')

# %%
user_interaction
# Out:
#                   user_id      pratilipi_id  read_percent  \
# 0        5506791961876448  1377786228262109         100.0
# 1        5506791971543560  1377786223038206          40.0
# 2        5506791996468218  1377786227025240         100.0
# 3        5506791978752866  1377786222398208          65.0
# 4        5506791978962946  1377786228157051         100.0
# ...                   ...               ...           ...
# 2499995  5506791965506371  1377786228243175         100.0
# 2499996  5506791966125995  1377786221431279         100.0
# 2499997  5506791964496442  1377786226829597         100.0
# 2499998  5506791968781083  1377786226056467         100.0
# 2499999  5506791956021363  1377786226666757         100.0
#
#                       updated_at
# 0        2022-03-22 10:29:57.291
# 1        2022-03-19 13:49:25.660
# 2        2022-03-21 17:28:47.288
# 3        2022-03-21 07:39:25.183
# 4        2022-03-22 17:32:44.777
# ...                          ...
# ...

# %%
user_interaction['updated_at'].max()
# Out:
# '2022-03-23 00:08:25.306'

# %%
print("Unique Users:", user_interaction['user_id'].nunique())
print("Unique Pratilipis:", user_interaction['pratilipi_id'].nunique())
# Out:
# Unique Users: 243606
# Unique Pratilipis: 241405

# %%
user_interaction.isnull().sum()
# Out:
# user_id         0
# pratilipi_id    0
# read_percent    0
# updated_at      0
# dtype: int64

# %%
user_interaction['updated_at'] = pd.to_datetime(user_interaction['updated_at'])

# %%
user_interaction.describe()
# Out:
#             user_id  pratilipi_id  read_percent                     updated_at
# count  2.500000e+06  2.500000e+06  2.500000e+06                        2500000
# mean   5.489174e+15  1.369444e+15  9.324295e+01  2022-03-20 22:13:28.009030656
# min    3.257553e+15 -5.375940e+15  0.000000e+00     2022-03-18 15:14:41.827000
# 25%    5.506792e+15  1.377786e+15  1.000000e+02  2022-03-19 18:09:25.668249856
# 50%    5.506792e+15  1.377786e+15  1.000000e+02  2022-03-20 23:18:17.970999808
# 75%    5.506792e+15  1.377786e+15  1.000000e+02  2022-03-22 02:29:16.531249920
# max    5.506792e+15  1.377786e+15  2.400000e+03     2022-03-23 00:08:25.306000
# std    1.606705e+14  1.221756e+14  2.170149e+01                            NaN

# %%
meta_data = pd.read_csv('/content/drive/MyDrive/metadata_pratilipi.csv')

# %%
meta_data
# Out:
#                author_id      pratilipi_id    category_name  reading_time  \
# 0      -3418949279741297  1025741862639304      translation             0
# 1      -2270332351871840  1377786215601277      translation           171
# 2      -2270332352037261  1377786215601962      translation            92
# 3      -2270332352521845  1377786215640994      translation             0
# 4      -2270332349665658  1377786215931338      translation            47
# ...                  ...               ...              ...           ...
# 954496 -2270332337845247  1377786228358627  Horror-Marathon           304
# 954497 -2270332334263077  1377786228362002  Horror-Marathon           588
# 954498 -2270332350350076  1377786228362682  Horror-Marathon           359
# 954499 -2270332337845247  1377786228375726  Horror-Marathon           310
# 954500 -2270332334263077  1377786228376825  Horror-Marathon           534
#
#                  updated_at         published_at
# ...

# %%
meta_data.isnull().sum()
# Out:
# author_id        0
# pratilipi_id     0
# category_name    0
# reading_time     0
# updated_at       0
# published_at     7
# dtype: int64

# %%
meta_data.describe()
# Out:
#           author_id  pratilipi_id   reading_time
# count  9.545010e+05  9.545010e+05  954501.000000
# mean  -2.379597e+15  1.368571e+15     351.979334
# std    3.922020e+14  1.161105e+14     513.959547
# min   -9.070332e+15 -8.734611e+14       0.000000
# 25%   -2.270332e+15  1.377786e+15     111.000000
# 50%   -2.270332e+15  1.377786e+15     256.000000
# 75%   -2.270332e+15  1.377786e+15     461.000000
# max   -2.270332e+15  1.377786e+15   78983.000000

# %%
print("Unique Authors:", meta_data['author_id'].nunique())
print("Unique Pratilipis:", meta_data['pratilipi_id'].nunique())
print("Unique Categories:", meta_data['category_name'].nunique())
# Out:
# Unique Authors: 64900
# Unique Pratilipis: 486693
# Unique Categories: 45

# %%
user_interaction['updated_at'].min(), user_interaction['updated_at'].max()
# Out:
# (Timestamp('2022-03-18 15:14:41.827000'),
#  Timestamp('2022-03-23 00:08:25.306000'))

# %% [markdown]
# # Percentage of Pratilipis Fully Read (100% read_percentage)

# %%
# Percentage of pratilipis fully read
fully_read = user_interaction[user_interaction['read_percent'] == 100]
percent_fully_read = (len(fully_read) / len(user_interaction)) * 100

print(f"Percentage of pratilipis fully read: {percent_fully_read:.2f}%")
# Out:
# Percentage of pratilipis fully read: 87.03%

# %% [markdown]
# # Categories with the Most Interactions

# %%
# Merge user interactions with meta data for category information
merged_data = pd.merge(user_interaction, meta_data, on='pratilipi_id', how='left')

# Count interactions per category
category_interactions = merged_data['category_name'].value_counts()

print("Top Categories by Number of Interactions:")
print(category_interactions)
# Out:
# Top Categories by Number of Interactions:
# category_name
# romance                      1138297
# novels                        510985
# suspense                      436560
# family                        365690
# social                        212806
# action-and-adventure          189171
# entertainment                 143716
# women                         125483
# swahindi2                     110655
# horror                        108256
# shortstories                   79753
# fantasy                        68138
# life                           61887
# moral-inspiring                52307
# drama                          42127
# webseries                      41512
# Pratilipi-Awards-Hindi         38323
# comedy                         30359
# Pratilipi-kalamkar-samman      30055
# crime                          25154
# Indiawale                      18917
# mythology                      18721
# Serieswriting                  16104
# translation                    14336
# ...

# %%
category_interactions
# Out:
# category_name
# romance                      1138297
# novels                        510985
# suspense                      436560
# family                        365690
# social                        212806
# action-and-adventure          189171
# entertainment                 143716
# women                         125483
# swahindi2                     110655
# horror                        108256
# shortstories                   79753
# fantasy                        68138
# life                           61887
# moral-inspiring                52307
# drama                          42127
# webseries                      41512
# Pratilipi-Awards-Hindi         38323
# comedy                         30359
# Pratilipi-kalamkar-samman      30055
# crime                          25154
# Indiawale                      18917
# mythology                      18721
# Serieswriting                  16104
# translation                    14336
# experiences-and-memories       13351
# ...

# %%
# Plotting the top categories
category_interactions.head(10).plot(kind='bar', figsize=(10, 8), color='skyblue', edgecolor='black')
plt.title("Top Categories by Number of Interactions")
plt.xlabel("Category")
plt.ylabel("Number of Interactions")
plt.show()

# %% [markdown]
# # Do Users Prefer Shorter or Longer Stories (Based on reading time)?

# %%
# Convert published_at to datetime
meta_data['published_at'] = pd.to_datetime(meta_data['published_at'])

# %%
# Merge user interactions with meta data to get reading time
merged_data = pd.merge(user_interaction, meta_data, on='pratilipi_id', how='left')

# Group by reading time and calculate average read percentage
reading_time_pref = merged_data.groupby('reading_time')['read_percent'].mean()

# %%
# Plot preferences based on reading time
plt.figure(figsize=(10, 5))
plt.scatter(reading_time_pref.index, reading_time_pref.values, alpha=0.7, color='green')
plt.title("Read Percentage vs Reading Time")
plt.xlabel("Reading Time (seconds)")
plt.ylabel("Average Read Percentage")
plt.grid()
plt.show()

# %%
user_interaction['updated_at'].min(), user_interaction['updated_at'].max()
# Out:
# (Timestamp('2022-03-18 15:14:41.827000'),
#  Timestamp('2022-03-23 00:08:25.306000'))

# %% [markdown]
# # How Do Interactions Change Over Time?

# %%
# Resample interactions over days
interactions_over_time = user_interaction.set_index('updated_at').resample('D')['user_id'].count()

# Plot interactions over time
plt.figure(figsize=(10, 5))
interactions_over_time.plot(color='purple')
plt.title("User Interactions Over Time (Daily)")
plt.xlabel("Date")
plt.ylabel("Number of Interactions")
plt.grid()
plt.show()

# %%
# Plot number of pratilipis published over time
meta_data.set_index('published_at').resample('ME')['pratilipi_id'].count().plot(figsize=(10, 5), color='green')
plt.title("Pratilipis Published Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Pratilipis")
plt.show()
